# %%
# =========================
#   EDA - MERGE DATASET
# =========================

# (1) Setup inicial
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scripts.loader import load_merge_master

# (2) Carregar os dados (usando o loader.py)
MASTER_PATH = 'metadata/master_metadata_audio_balanced.csv'

try:
    df = load_merge_master(MASTER_PATH)
    print(f"Dataset carregado com sucesso: {MASTER_PATH}")
    print(f"Total de músicas no dataset: {len(df)}")
    display(df.head())
except Exception as e:
    print(f"❌ ERRO ao carregar o dataset: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       7 import matplotlib.pyplot as plt
#       8 import seaborn as sns
# ----> 9 from scripts.loader import load_merge_master
#      11 # (2) Carregar os dados (usando o loader.py)
#      12 MASTER_PATH = 'metadata/master_metadata_audio_balanced.csv'
#
# ModuleNotFoundError: No module named 'scripts.loader'

# %%
# (3) Resumo dos campos
print("\nCampos disponíveis:", df.columns.tolist())
print("\nInformações do DataFrame:")
display(df.info())
display(df.describe(include='all'))
# Out:
# Campos disponíveis: ['song_id', 'arousal', 'valence', 'split_40_30_30', 'split_70_15_15', 'quadrant', 'allmusic id', 'allmusic extraction date', 'artist', 'title', 'relevance', 'year', 'lowestyear', 'duration', 'moods', 'moodsall', 'moodsallweights', 'genres', 'genreweights', 'themes', 'themeweights', 'styles', 'styleweights', 'appearancestrackids', 'appearancesalbumids', 'sample', 'sampleurl', 'actualyear', 'num_genres', 'num_moodsall']
#
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   song_id                   3232 non-null   object
#  1   arousal                   3232 non-null   float64
#  2   valence                   3232 non-null   float64
#  3   split_40_30_30            0 non-null      float64
#  4   split_70_15_15            0 non-null      float64
#  5   quadrant                  3232 non-null   object
#  6   allmusic id               3232 non-null   object
#  7   allmusic extraction date  3232 non-null   object
#  8   artist                    3229 non-null   object
#  9   title                     3232 non-null   object
#  10  relevance                 3047 non-null   float64
#  11  year                      2919 non-null   object
#  12  lowestyear                2294 non-null   object
#  13  duration                  3071 non-null   float64
#  14  moods                     3047 non-null   object
#  15  moodsall                  3195 non-null   object
#  16  moodsallweights           3192 non-null   object
#  17  genres                    3200 non-null   object
#  18  genreweights              3200 non-null   object
#  19  themes                    2706 non-null   object
#  20  themeweights              2706 non-null   object
#  21  styles                    3027 non-null   object
#  22  styleweights              3027 non-null   object
#  23  appearancestrackids       2933 non-null   object
#  24  appearancesalbumids       2933 non-null   object
#  25  sample                    3047 non-null   float64
#  26  sampleurl                 3033 non-null   object
#  27  actualyear                3081 non-null   object
#  28  num_genres                10 non-null     float64
#  29  num_moodsall              10 non-null     float64
# dtypes: float64(9), object(21)
# memory usage: 757.6+ KB
# None
#              song_id      arousal      valence  split_40_30_30  \
# count           3232  3232.000000  3232.000000             0.0
# unique          3232          NaN          NaN             NaN
# top     MT0035322836          NaN          NaN             NaN
# freq               1          NaN          NaN             NaN
# mean             NaN     0.479090     0.513042             NaN
# std              NaN     0.135410     0.224633             NaN
# min              NaN     0.025000     0.000000             NaN
# 25%              NaN     0.375000     0.293750             NaN
# 50%              NaN     0.498750     0.502500             NaN
# 75%              NaN     0.576875     0.733125             NaN
# max              NaN     0.975000     0.975000             NaN
#
#         split_70_15_15 quadrant allmusic id allmusic extraction date  \
# count              0.0     3232        3232                     3232
# unique             NaN        4        3227                        2
# top                NaN       Q4   not_found                      Old
# freq               NaN      808           6                     3047
# mean               NaN      NaN         NaN                      NaN
# std                NaN      NaN         NaN                      NaN
# min                NaN      NaN         NaN                      NaN
# 25%                NaN      NaN         NaN                      NaN
# 50%                NaN      NaN         NaN                      NaN
# 75%                NaN      NaN         NaN                      NaN
# max                NaN      NaN         NaN                      NaN
#
#             artist           title  ...  themeweights  \
# count         3229            3232  ...          2706
# unique        1620            3091  ...           542
# top     Jimmy Reed  Billie's Blues  ...       9,9,9,9
# freq            31               6  ...           306
# mean           NaN             NaN  ...           NaN
# std            NaN             NaN  ...           NaN
# min            NaN             NaN  ...           NaN
# 25%            NaN             NaN  ...           NaN
# 50%            NaN             NaN  ...           NaN
# 75%            NaN             NaN  ...           NaN
# max            NaN             NaN  ...           NaN
#
#                                     styles styleweights  appearancestrackids  \
# count                                 3027         3027                 2933
# unique                                1562          497                 2933
# top     Club/Dance,Death Metal,Heavy Metal          9,9         MT0041030749
# freq                                    29          154                    1
# mean                                   NaN          NaN                  NaN
# std                                    NaN          NaN                  NaN
# min                                    NaN          NaN                  NaN
# 25%                                    NaN          NaN                  NaN
# 50%                                    NaN          NaN                  NaN
# 75%                                    NaN          NaN                  NaN
# max                                    NaN          NaN                  NaN
#
#               appearancesalbumids       sample  \
# count                        2933  3047.000000
# unique                       2731          NaN
# top     MW0000173961,MW0000173961          NaN
# freq                            7          NaN
# mean                          NaN     0.995405
# std                           NaN     0.067639
# min                           NaN     0.000000
# 25%                           NaN     1.000000
# 50%                           NaN     1.000000
# 75%                           NaN     1.000000
# max                           NaN     1.000000
#
#                                                 sampleurl actualyear  \
# count                                                3033       3081
# unique                                               3033         67
# top     http://rovimusic.rovicorp.com/playback.mp3?c=I...       2005
# freq                                                    1        187
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        num_genres num_moodsall
# count   10.000000    10.000000
# unique        NaN          NaN
# top           NaN          NaN
# freq          NaN          NaN
# mean     1.200000    11.200000
# std      0.632456     6.142746
# min      0.000000     0.000000
# 25%      1.000000     9.500000
# 50%      1.000000    12.500000
# 75%      1.750000    13.000000
# max      2.000000    23.000000
#
# [11 rows x 30 columns]

# %%
# (4) Contagem por Split (se existir)
for split_col in ['split_70_15_15', 'split_40_30_30']:
    if split_col in df.columns:
        display(df[split_col].value_counts())
        df[split_col].value_counts().plot.pie(autopct='%1.1f%%', title=f'Proporção de {split_col}')
        plt.ylabel('')
        plt.show()
# Out:
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)

# %%
# (5) Distribuição por Quadrante
if 'quadrant' in df.columns:
    sns.countplot(x='quadrant', data=df)
    plt.title('Distribuição por Quadrante Emocional')
    plt.xlabel('Quadrante')
    plt.ylabel('Nº de Músicas')
    plt.show()

# %%
# (6) Distribuição por Ano (year ou ActualYear)
for year_col in ['year', 'ActualYear', 'Year']:
    if year_col in df.columns:
        plt.figure(figsize=(10,4))
        sns.histplot(df[year_col].dropna(), bins=20, kde=True)
        plt.title(f'Distribuição por Ano ({year_col})')
        plt.xlabel('Ano')
        plt.ylabel('Nº de Músicas')
        plt.show()
        break

# %%
# (7) Distribuição por Gêneros (top 15)
for gcol in ['genres', 'Genres']:
    if gcol in df.columns:
        from collections import Counter
        gen = df[gcol].dropna().str.cat(sep=';').split(';')
        gen = [g.strip().lower() for g in gen if g.strip()]
        top_gen = Counter(gen).most_common(15)
        genres_df = pd.DataFrame(top_gen, columns=['Gênero', 'Frequência'])
        plt.figure(figsize=(10,5))
        sns.barplot(y='Gênero', x='Frequência', data=genres_df)
        plt.title('Top 15 Gêneros Musicais')
        plt.show()
        break

# %%
# (8) Top artistas e músicas
for acol in ['artist', 'Artist']:
    if acol in df.columns:
        top_artists = df[acol].value_counts().head(10)
        print('\nTop 10 artistas:')
        display(top_artists)
        top_artists.plot.bar(title='Top 10 Artistas')
        plt.xlabel('Artista')
        plt.ylabel('Nº de músicas')
        plt.show()
        break

for tcol in ['title', 'Title']:
    if tcol in df.columns:
        print('\nExemplo de músicas:')
        display(df[[tcol]].sample(10))
        break
# Out:
# Top 10 artistas:
# artist
# Jimmy Reed           31
# Billie Holiday       30
# Slayer               29
# Megadeth             27
# Gipsy Kings          27
# Ella Fitzgerald      21
# Louis Armstrong      20
# Bob Dylan            18
# Steven Halpern       16
# Lightnin' Hopkins    16
# Name: count, dtype: int64
# Exemplo de músicas:
#                                          title
# 1581                                  In Amber
# 1255                           Five Long Years
# 30                             Everybody Hurts
# 2262     Every Generation Got It's Own Disease
# 1216                             Dirge Inferno
# 862                          My Elusive Dreams
# 1455                            Lil' Boy Fresh
# 2978                          Shield Your Eyes
# 403   I'm an Old Cowhand (From the Rio Grande)
# 406                                    Mr. Man

# %%
# (9) Histograma de arousal e valence (se existirem)
for acol in ['arousal', 'valence']:
    if acol in df.columns:
        sns.histplot(df[acol], bins=20, kde=True)
        plt.title(f'Distribuição de {acol}')
        plt.xlabel(acol.capitalize())
        plt.ylabel('Nº de Músicas')
        plt.show()

# %%
# (10) Heatmap arousal x valence
if all(c in df.columns for c in ['arousal', 'valence']):
    plt.figure(figsize=(6,5))
    sns.scatterplot(data=df, x='valence', y='arousal', hue='quadrant' if 'quadrant' in df.columns else None, alpha=0.5)
    plt.title('Distribuição Arousal x Valence')
    plt.show()

# %%
# (11) Análise de dados faltantes
plt.figure(figsize=(12,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title('Mapa de Dados Faltantes')
plt.show()

print("EDA concluída! Tabelas prontas para o relatório final.")
# Out:
# EDA concluída! Salve gráficos ou copie tabelas para o relatório final.

# %%
# (12)  Análise de Correlação ---

print("\n--- Matriz de Correlação ---")

# Selecionar apenas as colunas numéricas que fazem sentido correlacionar
colunas_numericas = ['arousal', 'valence', 'duration', 'year', 'actualyear', 'num_genres', 'num_moodsall']

# Filtrar o DataFrame para garantir que só temos colunas existentes e numéricas
df_corr = df[colunas_numericas].dropna()

# Calcular a matriz de correlação
matriz_correlacao = df_corr.corr()

# Desenhar o heatmap para visualizar a matriz
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacao, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação entre Variáveis Numéricas')
plt.show()

display(matriz_correlacao)
# Out:
# --- Matriz de Correlação ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 colunas_numericas = ['arousal', 'valence', 'duration', 'year', 'actualyear', 'num_genres', 'num_moodsall']
#       8 # Filtrar o DataFrame para garantir que só temos colunas existentes e numéricas
# ----> 9 df_corr = df[colunas_numericas].dropna()
#      11 # Calcular a matriz de correlação
#      12 matriz_correlacao = df_corr.corr()
#
# NameError: name 'df' is not defined

# %%
# (13)  Análise de Outliers ---

print("\n--- Análise de Outliers para Arousal, Valence e Duração ---")

# Selecionar as colunas para a análise de outliers
colunas_outliers = ['arousal', 'valence', 'duration']

# Criar os box plots
plt.figure(figsize=(15, 5))
for i, coluna in enumerate(colunas_outliers):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(y=df[coluna])
    plt.title(f'Box Plot de {coluna.capitalize()}')

plt.tight_layout()
plt.show()
